# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Lets first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The **Loan_train.csv** data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# | -------------- | ------------------------------------------------------------------------------------- |
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Lets download the dataset

# %%
# !wget -O loan_train.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Out:
# --2021-01-24 14:55:03--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# loan_train.csv      100%[===================>]  22.56K  --.-KB/s    in 0s
#
# 2021-01-24 14:55:03 (113 MB/s) - ‘loan_train.csv’ saved [23101/23101]

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loan_train.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30       9/8/2016
# 1           2             2     PAIDOFF       1000     30       9/8/2016
# 2           3             3     PAIDOFF       1000     15       9/8/2016
# 3           4             4     PAIDOFF       1000     30       9/9/2016
# 4           6             6     PAIDOFF       1000     30       9/9/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   45  High School or Below    male
# 1  10/7/2016   33              Bechalor  female
# 2  9/22/2016   27               college    male
# 3  10/8/2016   28               college  female
# 4  10/8/2016   29               college    male

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.7-main
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.6.3              |   py37h7b6447c_0         626 KB  anaconda
#     argon2-cffi-20.1.0         |   py37h7b6447c_1          49 KB  anaconda
#     astor-0.8.1                |           py37_0          45 KB  anaconda
#     async_generator-1.10       |   py37h28b3542_0          38 KB  anaconda
#     biopython-1.78             |   py37h7b6447c_0         2.6 MB  anaconda
#     bokeh-2.2.3                |           py37_0         7.0 MB  anaconda
#     brotli-1.0.9               |       he6710b0_2         402 KB  anaconda
#     charls-2.1.0               |       he6710b0_2         153 KB  anaconda
#     cloudpickle-1.6.0          |             py_0          29 KB  anaconda
#     cytoolz-0.11.0             |   py37h7b6447c_0         367 KB  anaconda
#     dbus-1.13.18               |       hb2f20db_0         586 KB  anaconda
#     defusedxml-0.6.0           |             py_0          23 KB  anaconda
#     entrypoints-0.3            |           py37_0          12 KB  anaconda
#     expat-2.2.10               |       he6710b0_2         192 KB  anaconda
#     fontconfig-2.13.0          |       h9420a91_0         291 KB  anaconda
#     freetype-2.10.4            |       h5ab3b9f_0         901 KB  anaconda
#     giflib-5.1.4               |       h14c3975_1          78 KB  anaconda
#     gmpy2-2.0.8                |   py37h10f8cd9_2         165 KB  anaconda
#     grpcio-1.31.0              |   py37hf8bcb03_0         2.2 MB  anaconda
#     icu-58.2                   |       he6710b0_3        22.7 MB  anaconda
#     imagecodecs-2020.5.30      |   py37h567f118_1         6.1 MB  anaconda
#     importlib-metadata-2.0.0   |             py_1          35 KB  anaconda
#     importlib_metadata-2.0.0   |                1          11 KB  anaconda
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         176 KB  anaconda
#     jmespath-0.10.0            |             py_0          22 KB  anaconda
#     jupyter_client-6.1.7       |             py_0          76 KB  anaconda
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB  anaconda
#     jupyterlab_server-1.2.0    |             py_0          24 KB  anaconda
#     jxrlib-1.1                 |       h7b6447c_2         238 KB  anaconda
#     lerc-2.2                   |       he6710b0_0         211 KB  anaconda
#     libaec-1.0.4               |       he6710b0_1          35 KB  anaconda
#     libpng-1.6.37              |       hbc83047_0         364 KB  anaconda
#     libprotobuf-3.13.0.1       |       hd408876_0         2.3 MB  anaconda
#     libtiff-4.1.0              |       h2733197_1         607 KB  anaconda
#     libuuid-1.0.3              |       h1bed415_2          16 KB  anaconda
#     libwebp-1.0.1              |       h8e7db2f_0         913 KB  anaconda
#     libxcb-1.14                |       h7b6447c_0         610 KB  anaconda
#     libxml2-2.9.10             |       hb55368b_3         1.3 MB  anaconda
#     libzopfli-1.0.3            |       he6710b0_0         179 KB  anaconda
#     lz4-c-1.9.2                |       heb0550a_3         203 KB  anaconda
#     markupsafe-1.1.1           |   py37h14c3975_1          26 KB  anaconda
#     mistune-0.8.4              |py37h14c3975_1001          53 KB  anaconda
#     mkl-2019.4                 |              243       204.1 MB  anaconda
#     mpc-1.1.0                  |       h10f8cd9_1          94 KB  anaconda
#     mpfr-4.0.2                 |       hb69a4c5_1         653 KB  anaconda
#     nbclient-0.5.1             |             py_0          60 KB  anaconda
#     nbconvert-6.0.7            |           py37_0         530 KB  anaconda
#     ncurses-6.2                |       he6710b0_1         1.1 MB  anaconda
#     networkx-2.5               |             py_0         1.2 MB  anaconda
#     openjpeg-2.3.0             |       h05c96fa_1         456 KB  anaconda
#     packaging-20.4             |             py_0          35 KB  anaconda
#     pandoc-2.11                |       hb0f4dca_0        12.5 MB  anaconda
#     pandocfilters-1.4.2        |           py37_1          13 KB  anaconda
#     prompt-toolkit-3.0.8       |             py_0         244 KB  anaconda
#     protobuf-3.13.0.1          |   py37he6710b0_1         700 KB  anaconda
#     pyjwt-1.7.1                |           py37_0          32 KB  anaconda
#     pyparsing-2.4.7            |             py_0          64 KB  anaconda
#     pyrsistent-0.17.3          |   py37h7b6447c_0          89 KB  anaconda
#     pytorch-1.5.0              |cpu_py37hd91cbb3_0        33.3 MB  anaconda
#     scikit-image-0.17.2        |   py37hdf5156a_0        10.7 MB  anaconda
#     scikit-learn-0.23.2        |   py37h0573a6f_0         6.9 MB  anaconda
#     scipy-1.5.2                |   py37h0b6359f_0        18.5 MB  anaconda
#     tabulate-0.8.7             |           py37_0          40 KB  anaconda
#     toml-0.10.1                |             py_0          20 KB  anaconda
#     traitlets-5.0.5            |             py_0          81 KB  anaconda
#     typing_extensions-3.7.4.3  |             py_0          29 KB  anaconda
#     unixodbc-2.3.9             |       h7b6447c_0         299 KB  anaconda
#     urllib3-1.25.11            |             py_0          93 KB  anaconda
#     wcwidth-0.2.5              |             py_0          37 KB  anaconda
#     webencodings-0.5.1         |           py37_1          19 KB  anaconda
#     xlsxwriter-1.3.7           |             py_0         104 KB  anaconda
#     zeromq-4.3.3               |       he6710b0_3         678 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       344.4 MB
#
# The following packages will be UPDATED:
#
#   intel-openmp           pkgs/main::intel-openmp-2019.4-243 --> anaconda::intel-openmp-2020.2-254
#   mkl_fft             pkgs/r::mkl_fft-1.0.14-py37hd81dba3_0 --> anaconda::mkl_fft-1.2.0-py37h23d657b_0
#   mkl_random         pkgs/r::mkl_random-1.0.4-py37hd81dba3~ --> anaconda::mkl_random-1.1.0-py37hd6b4f25_0
#   numpy                 pkgs/r::numpy-1.17.0-py37h7e9f1db_0 --> anaconda::numpy-1.19.1-py37hbc911f0_0
#   numpy-base         pkgs/r::numpy-base-1.17.0-py37hde5b4d~ --> anaconda::numpy-base-1.19.1-py37hfa32c7d_0
#   sip                  pkgs/main::sip-4.19.8-py37hf484d3e_0 --> anaconda::sip-4.19.24-py37he6710b0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex                                   pkgs/main --> anaconda
#   _py-xgboost-mutex                               pkgs/main --> anaconda
#   _pytorch_select                                 pkgs/main --> anaconda
#   absl-py            pkgs/main/noarch::absl-py-0.11.0-pyhd~ --> anaconda/linux-64::absl-py-0.10.0-py37_0
#   aiohttp                                         pkgs/main --> anaconda
#   argon2-cffi                                     pkgs/main --> anaconda
#   astor                                           pkgs/main --> anaconda
#   astropy             pkgs/main::astropy-4.2-py37h27cfd23_0 --> anaconda::astropy-4.0.2-py37h7b6447c_0
#   async-timeout                                   pkgs/main --> anaconda
#   async_generator                                 pkgs/main --> anaconda
#   attrs                pkgs/main::attrs-20.3.0-pyhd3eb1b0_0 --> anaconda::attrs-20.2.0-py_0
#   backcall                                        pkgs/main --> anaconda
#   beautifulsoup4     pkgs/main::beautifulsoup4-4.9.3-pyha8~ --> anaconda::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   biopython                                       pkgs/main --> anaconda
#   blas                                            pkgs/main --> anaconda
#   bleach               pkgs/main::bleach-3.2.2-pyhd3eb1b0_0 --> anaconda::bleach-3.2.1-py_0
#   blinker                                         pkgs/main --> anaconda
#   blosc                  pkgs/main::blosc-1.20.1-hd408876_0 --> anaconda::blosc-1.19.0-hd408876_0
#   bokeh                                           pkgs/main --> anaconda
#   boto3               pkgs/main::boto3-1.16.55-pyhd3eb1b0_0 --> anaconda::boto3-1.16.0-py_0
#   botocore           pkgs/main::botocore-1.19.57-pyhd3eb1b~ --> anaconda::botocore-1.19.1-py_0
#   brotli                                          pkgs/main --> anaconda
#   brotlipy           pkgs/main::brotlipy-0.7.0-py37h27cfd2~ --> anaconda::brotlipy-0.7.0-py37h7b6447c_1000
#   bzip2                                           pkgs/main --> anaconda
#   c-ares                pkgs/main::c-ares-1.17.1-h27cfd23_0 --> anaconda::c-ares-1.16.1-h7b6447c_0
#   ca-certificates    pkgs/main::ca-certificates-2021.1.19-~ --> anaconda::ca-certificates-2020.10.14-0
#   cachetools         pkgs/main::cachetools-4.2.0-pyhd3eb1b~ --> anaconda::cachetools-4.1.1-py_0
#   certifi            pkgs/main::certifi-2020.12.5-py37h06a~ --> anaconda::certifi-2020.6.20-py37_0
#   cffi                pkgs/main::cffi-1.14.4-py37h261ae71_0 --> anaconda::cffi-1.14.3-py37he30daa8_0
#   chardet            pkgs/main::chardet-3.0.4-py37h06a4308~ --> anaconda::chardet-3.0.4-py37_1003
#   charls                                          pkgs/main --> anaconda
#   click                 pkgs/main::click-7.1.2-pyhd3eb1b0_0 --> anaconda::click-7.1.2-py_0
#   cloudpickle                                     pkgs/main --> anaconda
#   cryptography       pkgs/main::cryptography-3.3.1-py37h3c~ --> anaconda::cryptography-3.1.1-py37h1ba5d50_0
#   cx_oracle          pkgs/main::cx_oracle-8.1.0-py37h27cfd~ --> anaconda::cx_oracle-8.0.1-py37h7b6447c_0
#   cycler                                          pkgs/main --> anaconda
#   cytoolz                                         pkgs/main --> anaconda
#   dask-core          pkgs/main::dask-core-2021.1.0-pyhd3eb~ --> anaconda::dask-core-2.30.0-py_0
#   dbus                                            pkgs/main --> anaconda
#   decorator                                       pkgs/main --> anaconda
#   defusedxml                                      pkgs/main --> anaconda
#   dill                   pkgs/main::dill-0.3.3-pyhd3eb1b0_0 --> anaconda::dill-0.3.2-py_0
#   docutils                                        pkgs/main --> anaconda
#   entrypoints                                     pkgs/main --> anaconda
#   expat                                           pkgs/main --> anaconda
#   fontconfig                                      pkgs/main --> anaconda
#   freetds                                         pkgs/main --> anaconda
#   freetype                                        pkgs/main --> anaconda
#   future                                          pkgs/main --> anaconda
#   gast                                            pkgs/main --> anaconda
#   giflib                                          pkgs/main --> anaconda
#   glib                    pkgs/main::glib-2.66.1-h92f7085_0 --> anaconda::glib-2.56.2-hd408876_0
#   gmp                       pkgs/main::gmp-6.1.2-h6c8ec71_1 --> anaconda::gmp-6.1.2-hb3b607b_0
#   gmpy2                                           pkgs/main --> anaconda
#   google-auth        pkgs/main::google-auth-1.24.0-pyhd3eb~ --> anaconda::google-auth-1.22.1-py_0
#   google-auth-oauth~ pkgs/main::google-auth-oauthlib-0.4.2~ --> anaconda::google-auth-oauthlib-0.4.1-py_2
#   google-pasta                                    pkgs/main --> anaconda
#   grpcio                                          pkgs/main --> anaconda
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.0-h8~ --> anaconda::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          pkgs/main::gstreamer-1.14.0-h28cd5cc_2 --> anaconda::gstreamer-1.14.0-hb453b48_1
#   h5py                                            pkgs/main --> anaconda
#   hdf5                                            pkgs/main --> anaconda
#   html5lib                                        pkgs/main --> anaconda
#   icu                                             pkgs/main --> anaconda
#   idna                    pkgs/main::idna-2.10-pyhd3eb1b0_0 --> anaconda::idna-2.10-py_0
#   imagecodecs        pkgs/main::imagecodecs-2021.1.11-py37~ --> anaconda::imagecodecs-2020.5.30-py37h567f118_1
#   imageio                                         pkgs/main --> anaconda
#   importlib-metadata                              pkgs/main --> anaconda
#   importlib_metadata                              pkgs/main --> anaconda
#   iniconfig          pkgs/main::iniconfig-1.1.1-pyhd3eb1b0~ --> anaconda::iniconfig-1.1.1-py_0
#   ipykernel                                       pkgs/main --> anaconda
#   ipython            pkgs/main::ipython-7.19.0-py37hb070fc~ --> anaconda::ipython-7.18.1-py37h5ca1d4c_0
#   ipython_genutils   pkgs/main/noarch::ipython_genutils-0.~ --> anaconda/linux-64::ipython_genutils-0.2.0-py37_0
#   ipywidgets         pkgs/main::ipywidgets-7.6.3-pyhd3eb1b~ --> anaconda::ipywidgets-7.5.1-py_1
#   jedi                pkgs/main::jedi-0.18.0-py37h06a4308_1 --> anaconda::jedi-0.17.2-py37_0
#   jeepney             pkgs/main::jeepney-0.6.0-pyhd3eb1b0_0 --> anaconda::jeepney-0.4.3-py_0
#   jinja2              pkgs/main::jinja2-2.11.2-pyhd3eb1b0_0 --> anaconda::jinja2-2.11.2-py_0
#   jmespath                                        pkgs/main --> anaconda
#   joblib               pkgs/main::joblib-1.0.0-pyhd3eb1b0_0 --> anaconda::joblib-0.17.0-py_0
#   jpeg                        pkgs/main::jpeg-9b-h024ee3a_2 --> anaconda::jpeg-9b-habf39ab_1
#   json5                                           pkgs/main --> anaconda
#   jsonschema                                      pkgs/main --> anaconda
#   jupyter_client                                  pkgs/main --> anaconda
#   jupyter_core       pkgs/main::jupyter_core-4.7.0-py37h06~ --> anaconda::jupyter_core-4.6.3-py37_0
#   jupyterlab                                      pkgs/main --> anaconda
#   jupyterlab_pygmen~                              pkgs/main --> anaconda
#   jupyterlab_server                               pkgs/main --> anaconda
#   jxrlib                                          pkgs/main --> anaconda
#   keras-applications                              pkgs/main --> anaconda
#   keras-preprocessi~                              pkgs/main --> anaconda
#   keyring                                         pkgs/main --> anaconda
#   kiwisolver         pkgs/main::kiwisolver-1.3.0-py37h2531~ --> anaconda::kiwisolver-1.2.0-py37hfd86e86_0
#   krb5                                            pkgs/main --> anaconda
#   lcms2                                           pkgs/main --> anaconda
#   ld_impl_linux-64                                pkgs/main --> anaconda
#   lerc                     pkgs/main::lerc-2.2.1-h2531618_0 --> anaconda::lerc-2.2-he6710b0_0
#   libaec                                          pkgs/main --> anaconda
#   libedit                                         pkgs/main --> anaconda
#   libffi                                          pkgs/main --> anaconda
#   libgcc-ng                                       pkgs/main --> anaconda
#   libgfortran-ng                                  pkgs/main --> anaconda
#   libpng                                          pkgs/main --> anaconda
#   libpq                                           pkgs/main --> anaconda
#   libprotobuf                                     pkgs/main --> anaconda
#   libsodium                                       pkgs/main --> anaconda
#   libstdcxx-ng                                    pkgs/main --> anaconda
#   libtiff                                         pkgs/main --> anaconda
#   libuuid                                         pkgs/main --> anaconda
#   libwebp                                         pkgs/main --> anaconda
#   libxcb                                          pkgs/main --> anaconda
#   libxgboost                                      pkgs/main --> anaconda
#   libxml2                                         pkgs/main --> anaconda
#   libxslt                                         pkgs/main --> anaconda
#   libzopfli                                       pkgs/main --> anaconda
#   lxml                 pkgs/main::lxml-4.6.2-py37h9120a33_0 --> anaconda::lxml-4.6.1-py37hefd8a0e_0
#   lz4-c                   pkgs/main::lz4-c-1.9.3-h2531618_0 --> anaconda::lz4-c-1.9.2-heb0550a_3
#   lzo                                             pkgs/main --> anaconda
#   markdown           pkgs/main::markdown-3.3.3-py37h06a430~ --> anaconda::markdown-3.3.2-py37_0
#   markupsafe                                      pkgs/main --> anaconda
#   matplotlib         pkgs/main::matplotlib-3.3.2-h06a4308_0 --> anaconda::matplotlib-3.3.1-0
#   matplotlib-base    pkgs/main::matplotlib-base-3.3.2-py37~ --> anaconda::matplotlib-base-3.3.1-py37h817c723_0
#   mistune                                         pkgs/main --> anaconda
#   mkl                                             pkgs/main --> anaconda
#   mkl-service        pkgs/main::mkl-service-2.3.0-py37he8a~ --> anaconda::mkl-service-2.3.0-py37he904b0f_0
#   mock                   pkgs/main::mock-4.0.3-pyhd3eb1b0_0 --> anaconda::mock-4.0.2-py_0
#   more-itertools     pkgs/main::more-itertools-8.6.0-pyhd3~ --> anaconda::more-itertools-8.5.0-py_0
#   mpc                                             pkgs/main --> anaconda
#   mpfr                                            pkgs/main --> anaconda
#   mpmath                                          pkgs/main --> anaconda
#   multidict                                       pkgs/main --> anaconda
#   nbclient                                        pkgs/main --> anaconda
#   nbconvert                                       pkgs/main --> anaconda
#   nbformat           pkgs/main::nbformat-5.1.2-pyhd3eb1b0_1 --> anaconda::nbformat-5.0.8-py_0
#   ncurses                                         pkgs/main --> anaconda
#   nest-asyncio       pkgs/main::nest-asyncio-1.4.3-pyhd3eb~ --> anaconda::nest-asyncio-1.4.1-py_0
#   networkx                                        pkgs/main --> anaconda
#   ninja              pkgs/main::ninja-1.10.2-py37hff7bd54_0 --> anaconda::ninja-1.10.1-py37hfd86e86_0
#   nltk                                            pkgs/main --> anaconda
#   notebook           pkgs/main::notebook-6.2.0-py37h06a430~ --> anaconda::notebook-6.1.4-py37_0
#   numexpr            pkgs/main::numexpr-2.7.2-py37hb2eb853~ --> anaconda::numexpr-2.7.1-py37h423224d_0
#   oauthlib                                        pkgs/main --> anaconda
#   olefile                                         pkgs/main --> anaconda
#   openjpeg                                        pkgs/main --> anaconda
#   openssl              pkgs/main::openssl-1.1.1i-h27cfd23_0 --> anaconda::openssl-1.1.1h-h7b6447c_0
#   opt_einsum                                      pkgs/main --> anaconda
#   packaging          pkgs/main::packaging-20.8-pyhd3eb1b0_0 --> anaconda::packaging-20.4-py_0
#   pandas             pkgs/main::pandas-1.2.1-py37ha9443f7_0 --> anaconda::pandas-1.1.3-py37he6710b0_0
#   pandoc                                          pkgs/main --> anaconda
#   pandocfilters      pkgs/main::pandocfilters-1.4.3-py37h0~ --> anaconda::pandocfilters-1.4.2-py37_1
#   parso                 pkgs/main::parso-0.8.1-pyhd3eb1b0_0 --> anaconda::parso-0.7.0-py_0
#   patsy                                           pkgs/main --> anaconda
#   pcre                                            pkgs/main --> anaconda
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3~ --> anaconda/linux-64::pexpect-4.8.0-py37_1
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-p~ --> anaconda/linux-64::pickleshare-0.7.5-py37_1001
#   pillow             pkgs/main::pillow-8.1.0-py37he98fc37_0 --> anaconda::pillow-8.0.0-py37h9a89aac_0
#   pip                  pkgs/main::pip-20.3.3-py37h06a4308_0 --> anaconda::pip-20.2.4-py37_0
#   plotly              pkgs/main::plotly-4.14.3-pyhd3eb1b0_0 --> anaconda::plotly-4.11.0-py_0
#   pluggy                                          pkgs/main --> anaconda
#   prometheus_client  pkgs/main::prometheus_client-0.9.0-py~ --> anaconda::prometheus_client-0.8.0-py_0
#   prompt-toolkit                                  pkgs/main --> anaconda
#   protobuf                                        pkgs/main --> anaconda
#   psycopg2           pkgs/main::psycopg2-2.8.5-py37h3c74f8~ --> anaconda::psycopg2-2.8.5-py37h1ba5d50_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-py~ --> anaconda/linux-64::ptyprocess-0.6.0-py37_0
#   py                      pkgs/main::py-1.10.0-pyhd3eb1b0_0 --> anaconda::py-1.9.0-py_0
#   py-xgboost                                      pkgs/main --> anaconda
#   pyasn1                                          pkgs/main --> anaconda
#   pyasn1-modules                                  pkgs/main --> anaconda
#   pycparser                                       pkgs/main --> anaconda
#   pygments           pkgs/main::pygments-2.7.4-pyhd3eb1b0_0 --> anaconda::pygments-2.7.1-py_0
#   pyjwt                                           pkgs/main --> anaconda
#   pymssql                                         pkgs/main --> anaconda
#   pyodbc                                          pkgs/main --> anaconda
#   pyopenssl          pkgs/main::pyopenssl-20.0.1-pyhd3eb1b~ --> anaconda::pyopenssl-19.1.0-py_1
#   pyparsing          pkgs/main::pyparsing-2.4.7-pyhd3eb1b0~ --> anaconda::pyparsing-2.4.7-py_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py37h05f1152_2 --> anaconda::pyqt-5.9.2-py37h22d08a2_1
#   pyrsistent                                      pkgs/main --> anaconda
#   pyshp                                           pkgs/main --> anaconda
#   pysocks                                         pkgs/main --> anaconda
#   pytables                                        pkgs/main --> anaconda
#   pytest             pkgs/main::pytest-6.2.1-py37h06a4308_0 --> anaconda::pytest-6.1.1-py37_0
#   python                                          pkgs/main --> anaconda
#   python-dateutil                                 pkgs/main --> anaconda
#   pytorch                                         pkgs/main --> anaconda
#   pytz                  pkgs/main::pytz-2020.5-pyhd3eb1b0_0 --> anaconda::pytz-2020.1-py_0
#   pywavelets                                      pkgs/main --> anaconda
#   pyyaml             pkgs/main::pyyaml-5.4.1-py37h27cfd23_1 --> anaconda::pyyaml-5.3.1-py37h7b6447c_1
#   pyzmq              pkgs/main::pyzmq-20.0.0-py37h2531618_1 --> anaconda::pyzmq-19.0.2-py37he6710b0_1
#   qt                                              pkgs/main --> anaconda
#   readline                                        pkgs/main --> anaconda
#   regex              pkgs/main::regex-2020.11.13-py37h27cf~ --> anaconda::regex-2020.10.15-py37h7b6447c_0
#   requests           pkgs/main::requests-2.25.1-pyhd3eb1b0~ --> anaconda::requests-2.24.0-py_0
#   requests-oauthlib                               pkgs/main --> anaconda
#   retrying                                        pkgs/main --> anaconda
#   rsa                       pkgs/main::rsa-4.7-pyhd3eb1b0_1 --> anaconda::rsa-4.6-py_0
#   s3transfer         pkgs/main/noarch::s3transfer-0.3.4-py~ --> anaconda/linux-64::s3transfer-0.3.3-py37_1
#   scikit-image                                    pkgs/main --> anaconda
#   scikit-learn                                    pkgs/main --> anaconda
#   scipy                                           pkgs/main --> anaconda
#   seaborn            pkgs/main::seaborn-0.11.1-pyhd3eb1b0_0 --> anaconda::seaborn-0.11.0-py_0
#   secretstorage      pkgs/main::secretstorage-3.3.0-py37h0~ --> anaconda::secretstorage-3.1.2-py37_1
#   send2trash         pkgs/main/noarch::send2trash-1.5.0-py~ --> anaconda/linux-64::send2trash-1.5.0-py37_0
#   setuptools         pkgs/main::setuptools-51.3.3-py37h06a~ --> anaconda::setuptools-50.3.0-py37hb0f4dca_1
#   six                pkgs/main/linux-64::six-1.15.0-py37h0~ --> anaconda/noarch::six-1.15.0-py_0
#   snappy                                          pkgs/main --> anaconda
#   snowballstemmer    pkgs/main::snowballstemmer-2.1.0-pyhd~ --> anaconda::snowballstemmer-2.0.0-py_0
#   soupsieve           pkgs/main::soupsieve-2.1-pyhd3eb1b0_0 --> anaconda::soupsieve-2.0.1-py_0
#   sqlalchemy         pkgs/main::sqlalchemy-1.3.21-py37h27c~ --> anaconda::sqlalchemy-1.3.19-py37h7b6447c_0
#   sqlite                                          pkgs/main --> anaconda
#   statsmodels        pkgs/main::statsmodels-0.12.1-py37h27~ --> anaconda::statsmodels-0.12.0-py37h7b6447c_0
#   sympy               pkgs/main::sympy-1.7.1-py37h06a4308_0 --> anaconda::sympy-1.6.2-py37_0
#   tabulate                                        pkgs/main --> anaconda
#   tensorboard                                     pkgs/main --> anaconda
#   tensorflow-base                                 pkgs/main --> anaconda
#   tensorflow-estima~                              pkgs/main --> anaconda
#   termcolor                                       pkgs/main --> anaconda
#   terminado          pkgs/main::terminado-0.9.2-py37h06a43~ --> anaconda::terminado-0.9.1-py37_0
#   testpath                                        pkgs/main --> anaconda
#   threadpoolctl                                   pkgs/main --> anaconda
#   tifffile           pkgs/main/noarch::tifffile-2021.1.14-~ --> anaconda/linux-64::tifffile-2020.10.1-py37hdd07704_2
#   tk                                              pkgs/main --> anaconda
#   toml                                            pkgs/main --> anaconda
#   toolz                pkgs/main::toolz-0.11.1-pyhd3eb1b0_0 --> anaconda::toolz-0.11.1-py_0
#   tornado             pkgs/main::tornado-6.1-py37h27cfd23_0 --> anaconda::tornado-6.0.4-py37h7b6447c_1
#   tqdm                  pkgs/main::tqdm-4.55.1-pyhd3eb1b0_0 --> anaconda::tqdm-4.50.2-py_0
#   traitlets                                       pkgs/main --> anaconda
#   typing_extensions                               pkgs/main --> anaconda
#   unixodbc                                        pkgs/main --> anaconda
#   urllib3                                         pkgs/main --> anaconda
#   wcwidth                                         pkgs/main --> anaconda
#   webencodings                                    pkgs/main --> anaconda
#   werkzeug                                        pkgs/main --> anaconda
#   wheel                pkgs/main::wheel-0.36.2-pyhd3eb1b0_0 --> anaconda::wheel-0.35.1-py_0
#   widgetsnbextension                              pkgs/main --> anaconda
#   wrapt                                           pkgs/main --> anaconda
#   xlrd               pkgs/main/noarch::xlrd-2.0.1-pyhd3eb1~ --> anaconda/linux-64::xlrd-1.2.0-py37_0
#   xlsxwriter                                      pkgs/main --> anaconda
#   xz                                              pkgs/main --> anaconda
#   yaml                                            pkgs/main --> anaconda
#   yarl                 pkgs/main::yarl-1.6.3-py37h27cfd23_0 --> anaconda::yarl-1.6.2-py37h7b6447c_0
#   zeromq                                          pkgs/main --> anaconda
#   zipp                   pkgs/main::zipp-3.4.0-pyhd3eb1b0_0 --> anaconda::zipp-3.3.1-py_0
#   zlib                                            pkgs/main --> anaconda
#   zstd                     pkgs/main::zstd-1.4.5-h9ceee32_0 --> anaconda::zstd-1.4.4-h0b5b093_3
#
#
#
# Downloading and Extracting Packages
# scikit-image-0.17.2  | 10.7 MB   | ##################################### | 100%
# libuuid-1.0.3        | 16 KB     |                                       |   0% WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/include/uuid/uuid.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/pkgconfig/uuid.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.1.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.1.0.0.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.la.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/test/run_test.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/build.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/has_prefix.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/run_exports.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/include/uuid/uuid.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/pkgconfig/uuid.pc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.1.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.so.1.0.0.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.a.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/lib/libuuid.la.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/test/run_test.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/recipe/build.sh.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/has_prefix.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/run_exports.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# libuuid-1.0.3        | 16 KB     | ##################################### | 100%
# icu-58.2             | 22.7 MB   | ####################################3 |  98% WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ureldatefmt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ucsdet.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/utypes.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ucal.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/normalizer2.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/simpleformatter.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ufieldpositer.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/unorm.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/bytestrie.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/umsg.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/compactdecimalformat.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/stringpiece.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/locid.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/idna.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/datefmt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/uiter.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/udatpg.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ucurr.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/filteredbrk.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ubiditransform.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/coll.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/decimfmt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/udateintervalformat.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/umisc.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ucol.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/caniter.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/format.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/selfmt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/localpointer.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/curramt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/parsepos.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/timezone.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/uspoof.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/locdspnm.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/appendable.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/currunit.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/vtzone.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/tztrans.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/uscript.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/measure.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/ucasemap.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/stringtriebuilder.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/msgfmt.h.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/icu-58.2-he6710b0_3/include/unicode/docmain.h.  Please remove this file manually (you may need to reboot to free file handles)
# ...
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/tests.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/x_user_defined.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/SOURCES.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/PKG-INFO.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/dependency_links.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/test/run_test.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/LICENSE.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__pycache__/labels.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__pycache__/x_user_defined.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__pycache__/tests.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__pycache__/mklabels.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/labels.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/mklabels.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/__init__.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/tests.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings/x_user_defined.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/top_level.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/SOURCES.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/PKG-INFO.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg-info/dependency_links.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/test/run_test.py.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/meta.yaml.template.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/meta.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/recipe/conda_build_config.yaml.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/paths.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/about.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/index.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/LICENSE.txt.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/repodata_record.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/hash_input.json.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/files.  Please remove this file manually (you may need to reboot to free file handles)
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(140): Could not remove or rename /opt/conda/pkgs/webencodings-0.5.1-py37_1/info/git.  Please remove this file manually (you may need to reboot to free file handles)
# webencodings-0.5.1   | 19 KB     | ##################################### | 100%
# jupyterlab_pygments- | 8 KB      | ##################################### | 100%
# libaec-1.0.4         | 35 KB     | ##################################### | 100%
#
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libuuid-1.0.3-h1bed415_2.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/icu-58.2-he6710b0_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pyparsing-2.4.7-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/ncurses-6.2-he6710b0_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libxml2-2.9.10-hb55368b_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/jupyter_client-6.1.7-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/markupsafe-1.1.1-py37h14c3975_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/lz4-c-1.9.2-heb0550a_3.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/argon2-cffi-20.1.0-py37h7b6447c_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/entrypoints-0.3-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/packaging-20.4-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libxcb-1.14-h7b6447c_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libpng-1.6.37-hbc83047_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pandocfilters-1.4.2-py37_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/mistune-0.8.4-py37h14c3975_1001.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/defusedxml-0.6.0-py_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/fontconfig-2.13.0-h9420a91_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/libtiff-4.1.0-h2733197_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/pyjwt-1.7.1-py37_0.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')
# InvalidArchiveError('Error with archive /opt/conda/pkgs/webencodings-0.5.1-py37_1.tar.bz2.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week dont pay it off, so lets use Feature binarization to set a threshold values less then day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Lets convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
#
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Feature befor One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets defind feature sets, X:

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
#
# -   K Nearest Neighbor(KNN)
# -   Decision Tree
# -   Support Vector Machine
# -   Logistic Regression
#
# ** Notice:**
#
# -   You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# -   You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# -   You should include the code of the algorithm in the following cells.

# %% [markdown]
# # K Nearest Neighbor(KNN)
#
# Notice: You should find the best k to build the model with the best accuracy.
# **warning:** You should not use the **loan_test.csv** for finding the best k, however, you can split your train_loan.csv into train and test to find the best **k**.

# %% [markdown]
# # Decision Tree

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# First, download and load the test set:

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()

# %% [markdown]
# # Report
#
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# | ------------------ | ------- | -------- | ------- |
# | KNN                | ?       | ?        | NA      |
# | Decision Tree      | ?       | ?        | NA      |
# | SVM                | ?       | ?        | NA      |
# | LogisticRegression | ?       | ?        | ?       |

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description                                                             |
# | ----------------- | ------- | ------------- | ------------------------------------------------------------------------------ |
# | 2020-10-27        | 2.1     | Lakshmi Holla | Made changes in import statement due to updates in version of  sklearn library |
# | 2020-08-27        | 2.0     | Malika Singla | Added lab to GitLab                                                            |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
